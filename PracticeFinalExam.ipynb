# %% [markdown]
# NAME: Junhui Cho
# BU ID: U09465844

# %% [markdown]
# #            CS 237—Practice Final Exam -- Spring 2020
#
#
#
# You must complete 2 of the 3 problems on this exam for full credit. All problems are worth 48 points and you will get 4 points if you spell your name correctly at the top of this page.  Please leave blank, or draw an X through, or write “Do Not Grade,” at the top of  the problem you are eliminating.  I will grade the first 2 if I can not figure out your intention.   Circle or Boldface final answers.  You may use class materials, a Jupyter notebook, or an online calculator such as Wolfram Alpha, but you may not consult each other or google around for an answer.

# %% [markdown]
# ## Problem One (Circular Permutations).
#
# Suppose A, B, C, D, E, F, G, and H are 8 people who must sit together at a round table. Any way of arranging people in seats is the same if it consists merely of rotating people around the tables (e.g., everyone moves 2 seats clockwise).
# Show all work! Each of these questions is independent and represent separate problems.

# %% [markdown]
# #### Part A:
#
# Suppose the 8 consist of four couples (say, AB, CD, EF, GH) each of whom must sit together (i.e., no one can sit between these pairs) but otherwise there is no restriction. How many ways of arranging this group are there?

# %% [markdown]
# #### Part B:
#  Suppose A and B must sit together and, independently, C and D must sit together.  But these couples can not stand each other and there must be at least one person between these couples. How many ways of arranging this group are there?

# %% [markdown]
# #### Part C:
#  Suppose A, B, C, and D are women and E, F, G, and H are men, and the arrangement must alternate men and women, i.e., no men can sit together and no women can sit together. How many ways of seating are there?

# %% [markdown]
# ## Problem Two (Limit Theorems).
#
# We load on a plane 100 packages whose weights are independent continuous random variables that are uniformly distributed between 5 and 50 pounds. What is the probability that their total weight will exceed 3000 pounds?

# %% [markdown]
# #### Part A:
# Answer this question using the Markov Inequality.

# %% [markdown]
# <p>$P(X>=a) <= E(X)/a $</p>
# <p>E(X) = 550/2 = 275</p>
# <p>a = 3000</p>
# <p>P(X>=a) = 275/3000 </p>

# %% [markdown]
# #### Part B
# Answer this question using the Chebyshev Inequality.

# %% [markdown]
# <p>$P(|X-E(X)| >= b) <= Var(X)/b^2$</p>
# <p>Var(X) = (500-50)^2/12</p>
# <p>Var(X)/b^2 = 0.001875</p>

# %% [markdown]
# #### Part C:
# Answer this question using the Central Limit Theorem (you may use online calculators or a notebook to answer this).

# %% [markdown]
# ![Screen%20Shot%202020-05-03%20at%205.24.17%20PM.png](attachment:Screen%20Shot%202020-05-03%20at%205.24.17%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-05-03%20at%205.24.26%20PM.png](attachment:Screen%20Shot%202020-05-03%20at%205.24.26%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-05-03%20at%205.24.32%20PM.png](attachment:Screen%20Shot%202020-05-03%20at%205.24.32%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-05-03%20at%205.24.39%20PM.png](attachment:Screen%20Shot%202020-05-03%20at%205.24.39%20PM.png)

# %% [markdown]
# #### Part A:
#
# What are the assumptions for a valid Linear Model?

# %% [markdown]
# #### Part B:
# What can you determine from the the plot of the histogram alone?

# %% [markdown]
# #### Part C:
# What can you determine from the residual plot? Does it change your perspective on the histogram?

# %% [markdown]
# #### Part D:
# In your opinion, is this a valid Linear Model?
